# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
price_data = pd.read_csv("prices.txt", sep='\s+', header=None, index_col=None)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/1x/j7cms8w90n71y__h4q0x74180000gn/T/ipykernel_86280/3635417880.py:1: SyntaxWarning: invalid escape sequence '\s'
#   price_data = pd.read_csv("prices.txt", sep='\s+', header=None, index_col=None)

# %%
cols = [12]
price_data = price_data[price_data.columns[cols]]

# %%
plt.plot(price_data, '')
plt.ylabel('prices')
plt.show()

# %%
43, 49

17, 26, 28, 37
# Out:
# (17, 26, 28, 37)
