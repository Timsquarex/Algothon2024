# %%
import numpy as np
import pandas as pd

# %%
price_data_roc = pd.read_csv("prices.txt", sep='\s+', header=None, index_col=None)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/1x/j7cms8w90n71y__h4q0x74180000gn/T/ipykernel_17815/2634190250.py:1: SyntaxWarning: invalid escape sequence '\s'
#   price_data_roc = pd.read_csv("prices.txt", sep='\s+', header=None, index_col=None)

# %%
p = price_data_roc.loc[:,'0':'49']
n = price_data_roc.loc[:,'0':'49'].shift(periods=-10)
Instroc = ((p-n)/n) * 100
roc = Instroc.dropna()
print(roc)
# Out:
#            0         1         2         3         4         5         6   \
# 0   -1.029412  0.561404  0.082610  0.198334 -0.439518  5.519481  0.423280
# 1   -2.034884  1.678184  0.247934  0.198413 -1.251897  4.435484  0.317628
# 2   -2.320522  2.348281  0.103242  0.217779 -1.595745  3.899269  0.476443
# 3   -1.096491  1.868502 -0.020648  0.654502 -1.992032  3.094463  0.370566
# 4   -0.437956  1.095352 -0.020657  0.356648 -0.915157  3.104575  0.105988
# ..        ...       ...       ...       ...       ...       ...       ...
# 735 -1.065891 -1.153603  0.087835  0.645905 -1.785714  1.137800  0.000000
# 736 -1.162791 -0.978844 -0.021949  0.670055 -2.294709  1.651842  0.347625
# 737 -1.453488 -0.332121 -0.087816  0.739884 -1.766046  2.171137 -0.173210
# 738 -0.686275  0.602028 -0.065847  1.018754 -1.066464  3.112840 -0.634737
# 739 -0.874636  0.394820 -0.109769  0.950835 -1.047220  2.590674 -0.748417
#
#            7         8         9   ...        40        41        42  \
# ...

# %%
roc3 = roc.iloc[:,0:49].shift(periods=-10)
rocn = roc.iloc[:,0:49]

rocn
# Out:
#            0         1         2         3         4         5         6   \
# 0   -1.029412  0.561404  0.082610  0.198334 -0.439518  5.519481  0.423280
# 1   -2.034884  1.678184  0.247934  0.198413 -1.251897  4.435484  0.317628
# 2   -2.320522  2.348281  0.103242  0.217779 -1.595745  3.899269  0.476443
# 3   -1.096491  1.868502 -0.020648  0.654502 -1.992032  3.094463  0.370566
# 4   -0.437956  1.095352 -0.020657  0.356648 -0.915157  3.104575  0.105988
# ..        ...       ...       ...       ...       ...       ...       ...
# 735 -1.065891 -1.153603  0.087835  0.645905 -1.785714  1.137800  0.000000
# 736 -1.162791 -0.978844 -0.021949  0.670055 -2.294709  1.651842  0.347625
# 737 -1.453488 -0.332121 -0.087816  0.739884 -1.766046  2.171137 -0.173210
# 738 -0.686275  0.602028 -0.065847  1.018754 -1.066464  3.112840 -0.634737
# 739 -0.874636  0.394820 -0.109769  0.950835 -1.047220  2.590674 -0.748417
#
#            7         8         9   ...        39        40        41  \
# ...
